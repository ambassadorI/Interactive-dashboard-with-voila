# %%
from __future__ import print_function

import pandas as pd
import numpy as np

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import plotly
from plotly.offline import iplot
import plotly.express as px
import plotly.graph_objects as go
import folium
import requests

# %%
r = requests.get("https://covidnigeria.herokuapp.com/api") #covid19 raw data
data = r.json() #specifying the type of data

Samples_Tested = data["data"]['totalSamplesTested']
confirmed_cases = data["data"]["totalConfirmedCases"]
Active_cases = data["data"]["totalActiveCases"]
Death = data["data"]["death"]
Discharged = data["data"]["discharged"]
all_states = data["data"]["states"]

keys = all_states[0].keys() #getting the keys for the all_state dictionary
length = len(all_states[0])
No_of_states = len(all_states)

#Adding the headers to the new txt
with open('Nigeria_covid19_data.txt', 'w') as r:
    for key in keys:
        #print(key) #printing out all the keys
        r.write(key)
        r.write(',')
        
file = open("Nigeria_covid19_data.txt", "a")
file.write("\n")
for state in range(No_of_states):
    file.write("\n")
    for key in keys:
        data = all_states[state][key]
        data = str(data)
        #print(data)
        file.write(data)
        file.write(",")
file.close()

data = pd.read_csv("Nigeria_covid19_data.txt")
data = data[["state", "confirmedCases","casesOnAdmission", "discharged", "death"]]
data = data.rename(columns={"state":"State", "confirmedCases":"Total_Confirmed_case", "casesOnAdmission":"Total_Active_case", "discharged":"Total_Recovered", "death": "Total_Death"})

# %%
confirmed = data["Total_Confirmed_case"]
death = data["Total_Death"]
active = data["Total_Active_case"]
state = data["State"]
discharged = data["Total_Recovered"]

# %%
state_coordinates = pd.read_csv("MyWebApp/Nigeria State Coordinates.csv")

st = list(state_coordinates["STATES"])
lat = state_coordinates["LAT"]
long = state_coordinates["LONG"]

# %% [markdown]
# ## INTERACTIVE COVID-19 DASHBOARD MONITORING NIGERIA CASES

# %% [markdown]
# The COVID-19 pandemic in Nigeria is part of the worldwide pandemic of coronavirus disease 2019 (COVID-19) caused by severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2). The first confirmed case in Nigeria was announced on 27 of February, 2020, when an Italian citizen in Lagos tested positive for the virus. The Italian citizen who works in Nigeria had returned on 25 of February from Milan, Italy through the Murtala Muhammed International Airport, fell ill on 26 February and was transferred to Lagos State biosecurity facilities for isolation and testing.
# On 9 March 2020, a second case of the virus was reported in Ewekoro, Ogun State, a Nigerian citizen who had contact with the Italian citizen

# %%
webMap = folium.Map(location=[9.08,7.53], tiles="CartoDB positron", zoom_start=6, max_zoom=6, min_zoom=6)
confirm = np.array(confirmed)
num_st = len(st)
num_state = len(state)

def size(i):
    global sx
    for j in range (len(state)):
        state2 = str(state[j]).upper()
        if st[i] == state2:
            value = confirm[j]
            ac = active[j]
            dth = death[j]
            dc = discharged[j]
            if value > 1000:
                sx = 25
            elif 1000 > value > 500:
                sx = 15
            elif 500 > value > 200:
                sx = 10
            elif 200 > value > 1:
                sx = 5
            else:
                sx = 0
        else:
            pass
    return sx

def val(i,d):
    global d_out
    for j in range (len(state)):
        state2 = str(state[j]).upper()
        if st[i] == state2:
            if d == 'cc':
                d_out = confirm[j]
            if d == ac:
                d_out = active[j]
            if d == dth:
                d_out = death[j]
            if d == dc:
                d_out = discharged[j]
        else:
            pass
    return d_out



for i in range (num_st):
    folium.CircleMarker(
        location=[lat[i],long[i]], 
        fill = True,
        radius = size(i),
        fill_color = "red",
        color = "red",
        tooltip = "%s<br><br>Active: %s<br>Recovered: %s<br>Deaths: %s,"%(st[i],val(i,ac),val(i,dc),val(i,dth))
        ).add_to(webMap)

    
webMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Filtering through the 36 states to find the top 10 states in each category

# %%
def query(select):
    if select == "confirmed":
        fig = px.scatter(data.head(10), x="State", y="Total_Confirmed_case", size="Total_Confirmed_case", 
                         color="State", hover_name="State", size_max=60, title="10 States with the Highest Confirmed Cases")
        fig.update_layout()
    elif select == "active":
        fig = px.scatter(data.head(10).sort_values("Total_Active_case", ascending=False), 
                         x="State", y="Total_Active_case", size="Total_Active_case", color="State", hover_name="State", size_max=50, title="10 States with the Highest Active Cases")
        fig.update_layout()
    elif select == "discharged":
        fig = px.scatter(data.head(10).sort_values("Total_Recovered", ascending=False), 
                         x="State", y="Total_Recovered", size="Total_Recovered", color="State", hover_name="State", size_max=40, title="10 States with the Highest Recovery")
        fig.update_layout()
    elif select == "death":
        fig = px.scatter(data.head(10).sort_values("Total_Death", ascending=False), 
                         x="State", y="Total_Death", size="Total_Death", color="State", hover_name="State", size_max=30, title="10 States with the Highest Number of Deaths")
        fig.update_layout()
    fig.show()
    
interact(query, select=["confirmed","active","discharged","death"]);
# Out:
# interactive(children=(Dropdown(description='select', options=('confirmed', 'active', 'discharged', 'death'), v…

# %%
def Search_by_case_type (case):
    if case == "Confirmed Cases":
        trace = go.Bar(x=state, y=confirmed, name='Confirmed Cases')
        layout = go.Layout(title = "Total Confirmed Case in Each State")
    if case == "Active Case":
        trace = go.Bar(x=state, y=active, name='Total Active Case in Each State')
        layout = go.Layout(title = "Active Cases")
    if case == "Discharged":
        trace = go.Bar(x=state, y=discharged, name='Discharged')
        layout = go.Layout(title = "Total Discharged in Each State")
    if case == "Death":
        trace = go.Bar(x=state, y=death, name='Deaths')
        layout = go.Layout(title = "Death Toll")

    figure = go.Figure(data = trace, layout = layout)
    return figure.show()

interact(Search_by_case_type, case=["Confirmed Cases", "Active Case", "Discharged", "Death"]);
# Out:
# interactive(children=(Dropdown(description='case', options=('Confirmed Cases', 'Active Case', 'Discharged', 'D…

# %%
total_active = np.sum(np.array(active))
recovered  = np.sum(np.array(discharged))
total_death = np.sum(np.array(death))
total_confirmed = np.sum(np.array(confirmed))


def select_state(Select_State):
    st = Select_State.lower()
    if st == "nigeria":
        ac = total_active
        dc = recovered
        dth = total_death
        print("Total Confirmed: ", total_confirmed)
        report = ['Active Case', 'Death', 'Recovered']
        value = [ac, dth, dc]
        trace = go.Pie(labels = report, values = value)
        data = [trace]
    for i in range(len(state)):
        state1 = str(state[i]).lower()
        if state1 == st:
            print("Total confirmed: ", confirmed[i])
            ac = active[i]
            dc = discharged[i]
            dth = death[i]
            report = ['Active Case', 'Death', 'Recovered']
            value = [ac, dth, dc]
            trace = go.Pie(labels = report, values = value, title = "")
            data = [trace]
        else:
            pass
    fig = go.Figure(data = data)
    iplot(fig)
        
interact(select_state, Select_State=state);
# Out:
# interactive(children=(Dropdown(description='Select_State', options=('Lagos', 'FCT', 'Kano', 'Rivers', 'Oyo', '…

# %%
def highlight_col(x):
    r = "background-color: red"
    p = "background-color: purple"
    b = "background-color: blue"
    g = "background-color: green"
    temp_data = pd.DataFrame("", index=x.index, columns = x.columns)
    temp_data.iloc[:,2] = b
    temp_data.iloc[:,3] = g
    temp_data.iloc[:,4] = r
    return temp_data

data.style.apply(highlight_col, axis=None)
# Out:
# <style  type="text/css" >
#     #T_9eb990b4_b406_11ea_a661_0c54154d777brow0_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow0_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow0_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow1_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow1_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow1_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow2_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow2_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow2_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow3_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow3_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow3_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow4_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow4_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow4_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow5_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow5_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow5_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow6_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow6_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow6_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow7_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow7_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow7_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow8_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow8_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow8_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow9_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow9_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow9_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow10_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow10_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow10_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow11_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow11_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow11_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow12_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow12_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow12_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow13_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow13_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow13_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow14_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow14_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow14_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow15_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow15_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow15_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow16_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow16_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow16_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow17_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow17_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow17_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow18_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow18_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow18_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow19_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow19_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow19_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow20_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow20_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow20_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow21_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow21_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow21_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow22_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow22_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow22_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow23_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow23_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow23_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow24_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow24_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow24_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow25_col2 {
#             background-color:  blue;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow25_col3 {
#             background-color:  green;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow25_col4 {
#             background-color:  red;
#         }    #T_9eb990b4_b406_11ea_a661_0c54154d777brow26
